# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Salaries.csv")
df
# Out:
# C:\Users\Daniel\anaconda3\envs\corona_analysis\lib\site-packages\IPython\core\interactiveshell.py:3251: DtypeWarning: Columns (3,4,5,6,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# What is the average BasePay?

# %%
pd.to_numeric(df['BasePay'], errors='coerce').fillna(0).mean()
# Out:
# 66053.72928809702

# %% [markdown]
# What is the highest amount of OvertimePay in the dataset?

# %%
pd.to_numeric(df['OvertimePay'], errors='coerce').fillna(0).max()
# Out:
# 245131.88

# %% [markdown]
# What is the job title of JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesnt match up (theres also a lowercas Joseph Driscoll)

# %%
df[df['EmployeeName']=='JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %% [markdown]
# How much does JOSEPH DRISCOLL make (including benefits)?

# %%
df[df['EmployeeName']=='JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# What is the name of highest paid person (including benefits)?

# %%
max_ = df['TotalPayBenefits'].max()
df[df["TotalPayBenefits"]==max_]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN

# %%
# or...
df.loc[df['TotalPayBenefits'].idxmax()]
# Out:
# Id                                                               1
# EmployeeName                                        NATHANIEL FORD
# JobTitle            GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# BasePay                                                  167411.18
# OvertimePay                                                    0.0
# OtherPay                                                 400184.25
# Benefits                                                       NaN
# TotalPay                                                 567595.43
# TotalPayBenefits                                         567595.43
# Year                                                          2011
# Notes                                                          NaN
# Agency                                               San Francisco
# Status                                                         NaN
# Name: 0, dtype: object

# %% [markdown]
# What is the name of lowest paid person (including benefits)? Do you notice something strange abou thow much he or she is paid?

# %%
min_ = df['TotalPayBenefits'].min()
df[df["TotalPayBenefits"]==min_]
# Out:
#             Id EmployeeName                    JobTitle BasePay OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch    0.00        0.00
#
#        OtherPay Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653  -618.13     0.00   -618.13           -618.13  2014    NaN
#
#                Agency Status
# 148653  San Francisco     PT

# %%
df.loc[df['TotalPayBenefits'].idxmin()]
# Out:
# Id                                      148654
# EmployeeName                         Joe Lopez
# JobTitle            Counselor, Log Cabin Ranch
# BasePay                                   0.00
# OvertimePay                               0.00
# OtherPay                               -618.13
# Benefits                                  0.00
# TotalPay                               -618.13
# TotalPayBenefits                       -618.13
# Year                                      2014
# Notes                                      NaN
# Agency                           San Francisco
# Status                                      PT
# Name: 148653, dtype: object

# %% [markdown]
# What was the average (mean) BasePay of all employees per year? (2011 - 2014)?

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
df2 = df.copy()
df2 = df2[df2['BasePay'] != 'Not Provided']

# %%
df2['BasePay'] = pd.to_numeric(df2['BasePay'], errors='coerce').fillna(0)

# %%
df2.groupby('Year').mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    68509.832156
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# How many unique job titles are there?

# %%
df['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# What are the top 5 most common jobs?

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
df2_series = df2.groupby('JobTitle').count()['Id']
df2_series.sort_values(ascending=False)[:5]
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: Id, dtype: int64

# %%
# or...
df2['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %% [markdown]
# How many Job titles were represented by only one person in 2013? (e.g. Job titles with only one occurence in 2013)?

# %%
sum(df2[(df2['Year']==2013)]['JobTitle'].value_counts() == 1)
# Out:
# 202

# %% [markdown]
# How many people have the word 'Chief' in their job title?

# %%
def chief_string(title):
    if 'chief' in title.lower().split():
        return True
    else:
        return False

# %%
sum(df2['JobTitle'].apply(lambda x: chief_string(x)))
# Out:
# 477

# %% [markdown]
# Bonus: Is there a correlation between length of the Job title and Salary?

# %%
df2['title_len'] = df2['JobTitle'].apply(len)

# %%
df2[['JobTitle', 'title_len']]
# Out:
#                                               JobTitle  title_len
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY         46
# 1                      CAPTAIN III (POLICE DEPARTMENT)         31
# 2                      CAPTAIN III (POLICE DEPARTMENT)         31
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         36
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)         44
# ...                                                ...        ...
# 148649                                       Custodian          9
# 148650                                    Not provided         12
# 148651                                    Not provided         12
# 148652                                    Not provided         12
# 148653                      Counselor, Log Cabin Ranch         26
#
# [148654 rows x 2 columns]

# %%
df2[['TotalPayBenefits', 'title_len']].corr()
# Out:
#                   TotalPayBenefits  title_len
# TotalPayBenefits          1.000000  -0.036878
# title_len                -0.036878   1.000000

# %%
# No corr
