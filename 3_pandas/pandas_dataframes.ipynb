# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %%
np.random.seed(101) # set a random seed to get always same from random

# %%
df = pd.DataFrame(data=randn(5, 4), index=['A', 'B', 'C', 'D', 'E'], columns=['W', 'X', 'Y', 'Z'])
df
# every columns are just pd.Series
# dataframe = bunch of Series that share an index
# Out:
#           W         X         Y         Z
# A -1.467514 -0.494095 -0.162535  0.485809
# B  0.392489  0.221491 -0.855196  1.541990
# C  0.666319 -0.538235 -0.568581  1.407338
# D  0.641806 -0.905100 -0.391157  1.028293
# E -1.972605 -0.866885  0.720788 -1.223082

# %%
df['W']
# thats a series
# Out:
# A   -1.467514
# B    0.392489
# C    0.666319
# D    0.641806
# E   -1.972605
# Name: W, dtype: float64

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['W', 'Z']]
# thats a dataframe because multiple cols
# Out:
#           W         Z
# A -1.467514  0.485809
# B  0.392489  1.541990
# C  0.666319  1.407338
# D  0.641806  1.028293
# E -1.972605 -1.223082

# %%
type(df[['W', 'Z']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Adding columns

# %%
df['new'] = df['W'] + df['Y']
df
# Out:
#           W         X         Y         Z       new
# A -1.467514 -0.494095 -0.162535  0.485809 -1.630049
# B  0.392489  0.221491 -0.855196  1.541990 -0.462707
# C  0.666319 -0.538235 -0.568581  1.407338  0.097738
# D  0.641806 -0.905100 -0.391157  1.028293  0.250649
# E -1.972605 -0.866885  0.720788 -1.223082 -1.251818

# %% [markdown]
# Drop Columns

# %%
df.drop('new')
# wont work because axis=0 is default which are rows
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8740/2572820836.py in <module>
# ----> 1 df.drop('new')
#       2 # wont work because axis=0 is default which are rows
#
# ~\anaconda3\envs\dl\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\dl\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df.drop('new', axis=1)
# Out:
#           W         X         Y         Z
# A -1.467514 -0.494095 -0.162535  0.485809
# B  0.392489  0.221491 -0.855196  1.541990
# C  0.666319 -0.538235 -0.568581  1.407338
# D  0.641806 -0.905100 -0.391157  1.028293
# E -1.972605 -0.866885  0.720788 -1.223082

# %% [markdown]
# Inplace

# %%
df
# 'new' is still here
# Out:
#           W         X         Y         Z       new
# A -1.467514 -0.494095 -0.162535  0.485809 -1.630049
# B  0.392489  0.221491 -0.855196  1.541990 -0.462707
# C  0.666319 -0.538235 -0.568581  1.407338  0.097738
# D  0.641806 -0.905100 -0.391157  1.028293  0.250649
# E -1.972605 -0.866885  0.720788 -1.223082 -1.251818

# %%
df.drop('new', axis=1, inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A -1.467514 -0.494095 -0.162535  0.485809
# B  0.392489  0.221491 -0.855196  1.541990
# C  0.666319 -0.538235 -0.568581  1.407338
# D  0.641806 -0.905100 -0.391157  1.028293
# E -1.972605 -0.866885  0.720788 -1.223082

# %% [markdown]
# Drop Rows

# %%
df.drop('E', axis=0)
# Out:
#           W         X         Y         Z
# A -1.467514 -0.494095 -0.162535  0.485809
# B  0.392489  0.221491 -0.855196  1.541990
# C  0.666319 -0.538235 -0.568581  1.407338
# D  0.641806 -0.905100 -0.391157  1.028293

# %%
df.shape
# Out:
# (5, 4)

# %% [markdown]
# Selecting rows

# %%
df.loc['A']
# takes label as parameter
# Out:
# W   -1.467514
# X   -0.494095
# Y   -0.162535
# Z    0.485809
# Name: A, dtype: float64

# %%
df.iloc[0]
# takes index of the row, even if index is not num
# Out:
# W   -1.467514
# X   -0.494095
# Y   -0.162535
# Z    0.485809
# Name: A, dtype: float64

# %% [markdown]
# Selecting subsets

# %%
df.loc['B', 'Y']
# row B, column Y
# Out:
# -0.8551960407780934

# %%
df.loc[['A', 'B'], ['W', 'Y']]
# Out:
#           W         Y
# A -1.467514 -0.162535
# B  0.392489 -0.855196

# %% [markdown]
# # Part 2

# %%
df
# Out:
#           W         X         Y         Z
# A -1.467514 -0.494095 -0.162535  0.485809
# B  0.392489  0.221491 -0.855196  1.541990
# C  0.666319 -0.538235 -0.568581  1.407338
# D  0.641806 -0.905100 -0.391157  1.028293
# E -1.972605 -0.866885  0.720788 -1.223082

# %% [markdown]
# Conditional selection

# %%
df > 0
# Out:
#        W      X      Y      Z
# A  False  False  False   True
# B   True   True  False   True
# C   True  False  False   True
# D   True  False  False   True
# E  False  False   True  False

# %%
df[df > 0]
# Out:
#           W         X         Y         Z
# A       NaN       NaN       NaN  0.485809
# B  0.392489  0.221491       NaN  1.541990
# C  0.666319       NaN       NaN  1.407338
# D  0.641806       NaN       NaN  1.028293
# E       NaN       NaN  0.720788       NaN

# %%
df['W']>0
# returns Series
# Out:
# A    False
# B     True
# C     True
# D     True
# E    False
# Name: W, dtype: bool

# %%
df[df['W']>0]
# only returns True rows
# returns dataframe
# Out:
#           W         X         Y         Z
# B  0.392489  0.221491 -0.855196  1.541990
# C  0.666319 -0.538235 -0.568581  1.407338
# D  0.641806 -0.905100 -0.391157  1.028293

# %%
result_df = df[df['W']<0]

# %%
result_df['X']
# Out:
# A   -0.494095
# E   -0.866885
# Name: X, dtype: float64

# %%
df[df['W']<0]['X']
# Out:
# A   -0.494095
# E   -0.866885
# Name: X, dtype: float64

# %%
df[df['W']<0][['Y', 'X']]
# row W < 0
# cols only Y, X
# Out:
#           Y         X
# A -0.162535 -0.494095
# E  0.720788 -0.866885

# %% [markdown]
# Multiple Conditions

# %%
df
# Out:
#           W         X         Y         Z
# A -1.467514 -0.494095 -0.162535  0.485809
# B  0.392489  0.221491 -0.855196  1.541990
# C  0.666319 -0.538235 -0.568581  1.407338
# D  0.641806 -0.905100 -0.391157  1.028293
# E -1.972605 -0.866885  0.720788 -1.223082

# %%
df[(df['W'] > 0) and df['Y'] > 1]
# error, because python 'and' operator can not deal with mutliple instances of bool values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8740/3843978001.py in <module>
# ----> 1 df[(df['W'] > 0) and df['Y'] > 1]
#       2 # error, because python 'and' operator can not deal with mutliple instances of bool values
#
# ~\anaconda3\envs\dl\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df[(df['W'] < 0) & (df['Y'] < 1)]
# Out:
#           W         X         Y         Z
# A -1.467514 -0.494095 -0.162535  0.485809
# E -1.972605 -0.866885  0.720788 -1.223082

# %% [markdown]
# Reseting index

# %%
df
# Out:
#           W         X         Y         Z
# A -1.467514 -0.494095 -0.162535  0.485809
# B  0.392489  0.221491 -0.855196  1.541990
# C  0.666319 -0.538235 -0.568581  1.407338
# D  0.641806 -0.905100 -0.391157  1.028293
# E -1.972605 -0.866885  0.720788 -1.223082

# %%
df.reset_index()
# old index will reset to new column
# not inplace
# Out:
#   index         W         X         Y         Z
# 0     A -1.467514 -0.494095 -0.162535  0.485809
# 1     B  0.392489  0.221491 -0.855196  1.541990
# 2     C  0.666319 -0.538235 -0.568581  1.407338
# 3     D  0.641806 -0.905100 -0.391157  1.028293
# 4     E -1.972605 -0.866885  0.720788 -1.223082

# %%
new_index = 'CA NY WY OR CO'.split()
new_index
# Out:
# ['CA', 'NY', 'WY', 'OR', 'CO']

# %%
df['States'] = new_index
df
# Out:
#           W         X         Y         Z States
# A -1.467514 -0.494095 -0.162535  0.485809     CA
# B  0.392489  0.221491 -0.855196  1.541990     NY
# C  0.666319 -0.538235 -0.568581  1.407338     WY
# D  0.641806 -0.905100 -0.391157  1.028293     OR
# E -1.972605 -0.866885  0.720788 -1.223082     CO

# %%
df.set_index('States')
# Out:
#                W         X         Y         Z
# States
# CA     -1.467514 -0.494095 -0.162535  0.485809
# NY      0.392489  0.221491 -0.855196  1.541990
# WY      0.666319 -0.538235 -0.568581  1.407338
# OR      0.641806 -0.905100 -0.391157  1.028293
# CO     -1.972605 -0.866885  0.720788 -1.223082

# %% [markdown]
# # Part 3
