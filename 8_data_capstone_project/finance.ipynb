# %%
import pandas as pd
import numpy as np
import datetime
from pandas_datareader import data, wb

# visuals
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
# %matplotlib inline
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
BAC = data.DataReader('BAC', 'yahoo', datetime.datetime(2006, 1, 1), datetime.datetime(2016, 1, 1))
# citigroup
C = data.DataReader('C', 'yahoo', datetime.datetime(2006, 1, 1), datetime.datetime(2016, 1, 1))
# goldman sachs
GS = data.DataReader('GS', 'yahoo', datetime.datetime(2006, 1, 1), datetime.datetime(2016, 1, 1))
#jpmorgan
JPM = data.DataReader('JPM', 'yahoo', datetime.datetime(2006, 1, 1), datetime.datetime(2016, 1, 1))
#morgan stanley
MS = data.DataReader('MS', 'yahoo', datetime.datetime(2006, 1, 1), datetime.datetime(2016, 1, 1))
# well fargo
WFC = data.DataReader('WFC', 'yahoo', datetime.datetime(2006, 1, 1), datetime.datetime(2016, 1, 1))

# %% [markdown]
# Create a list of the ticker symbols (as strings) in alphabetic order. Call this list: tickers

# %%
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %% [markdown]
# Use pd.concat to concatenate the bank dataframes together to a single dataframe called 'bank_stocks'. Set the keys argument equal to the tickers list. Also pay attention to what axis you concatenate on.

# %%
bank_stocks = pd.concat([BAC, C, GS, JPM, MS, WFC], keys=tickers, axis=1)
bank_stocks.head()
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  33.942665
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  33.582176
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  33.625446
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  33.574966
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  33.596596
#
#                      C                                      ...         MS  \
#                   High         Low        Open       Close  ...       Open
# Date                                                        ...
# 2006-01-03  493.799988  481.100006  490.000000  492.899994  ...  57.169998
# 2006-01-04  491.000000  483.500000  488.600006  483.799988  ...  58.700001
# ...

# %% [markdown]
# Set the column name levels (this is filled out for you)

# %%
bank_stocks.columns.names = ['Bank Ticker', 'Stock Info']
bank_stocks.head()
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05   46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06   46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09   46.970001  46.360001  46.720001  46.599998  15619400.0
#
# Bank Ticker                      C                                      ...  \
# Stock Info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-01-03   33.942665  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04   33.582176  491.000000  483.500000  488.600006  483.799988  ...
# 2006-01-05   33.625446  487.799988  484.000000  484.399994  486.200012  ...
# ...

# %% [markdown]
# # Exploritory Data Analysis

# %% [markdown]
# What is the max close price for each banks stock throughout the time period?

# %%
bank_stocks['BAC']['Close'].max()
# Out:
# 54.900001525878906

# %%
for tick in tickers:
    print(bank_stocks[tick]['Close'].max())
# Out:
# 54.900001525878906
# 564.0999755859375
# 247.9199981689453
# 70.08000183105469
# 89.30000305175781
# 58.52000045776367

# %%
# or...
bank_stocks.xs(key='Close', axis=1, level='Stock Info').max()
# give me the 'close' column for all banks
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %% [markdown]
# Create a new empty Dataframe called returns. This dataframe will contain the returns for each banks stock. Returns formula is:

# %%
returns = pd.DataFrame()

# %% [markdown]
# We can use pandas pct_change() method on the close column to create a column representing this return value. Create a for loop that goes and for each bank stock ticker creates this return column and sets it as a column in the returns dataframe

# %%
for tick in tickers:
    returns[tick + ' Return'] = bank_stocks[tick]['Close'].pct_change()

# %%
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158

# %% [markdown]
# Create a pairplot using seaborn of the returns dataframe. What stock stand out?

# %%
sns.pairplot(returns[1:]) # cause of NaN

# %% [markdown]
# Using this returns dataframe, figure out on what dates each bank stock had the best and worst single day returns. You should notice that 4 of the banks share the same day for the worst drop, did anything significant happen that day?

# %%
returns
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158
# ...                ...       ...        ...         ...        ...         ...
# 2015-12-24   -0.004037  0.001520  -0.002624   -0.001948  -0.003681   -0.003997
# 2015-12-28   -0.008107 -0.006261  -0.004658   -0.003303  -0.009544   -0.002554
# 2015-12-29    0.008757  0.011455   0.010516    0.010395   0.011812    0.011156
# 2015-12-30   -0.013310 -0.012835  -0.008282   -0.007157  -0.009831   -0.007235
# 2015-12-31   -0.012903 -0.010516  -0.009780   -0.008410  -0.013031   -0.009656
#
# ...

# %%
returns.idxmin()
# Out:
# BAC Return   2009-01-20
# C Return     2009-02-27
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2008-11-24
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# Take a look at the standard deviation of the returns, which stock would you classify as the riskiest over the entire time period? Which would you classify as the riskiest for the year 2015? High standard deviation of returns mean high risky stock

# %%
returns.std()
# Out:
# BAC Return    0.036647
# C Return      0.038672
# GS Return     0.025390
# JPM Return    0.027667
# MS Return     0.037819
# WFC Return    0.030238
# dtype: float64

# %%
returns.loc['2015-01-01': '2015-12-31'].std()
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %% [markdown]
# Create a distplot using seaborn of the 2015 returns for Morgan Stanley

# %%
sns.displot(data=returns.loc['2015-01-01': '2015-12-31']['MS Return'])

# %%
# or...
sns.displot(data=returns['MS Return'].loc['2015'], bins=50)
# pretty stable returns

# %% [markdown]
# Create a distplot using seaborn of the 2008 returns for CitiGroup

# %%
sns.displot(data=returns['C Return'].loc['2008'], color='red', bins=50)
# need to explore what happened to citigroup during this year

# %% [markdown]
# # Move visualizations

# %% [markdown]
# Create a line plot showing Close price for each bank for the entire index of time. (Hint: Try using a for loop, or use .xs to get a cross section of the data)

# %%
bank_stocks.head()
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05   46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06   46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09   46.970001  46.360001  46.720001  46.599998  15619400.0
#
# Bank Ticker                      C                                      ...  \
# Stock Info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-01-03   33.942665  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04   33.582176  491.000000  483.500000  488.600006  483.799988  ...
# 2006-01-05   33.625446  487.799988  484.000000  484.399994  486.200012  ...
# ...

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(label=tick, figsize=(20, 10))
plt.legend()

# %%
# or...
plt.figure(figsize=(20, 10))
sns.lineplot(data=bank_stocks.xs(key='Close', axis=1, level='Stock Info'))
plt.legend()

# %%
bank_stocks.xs(key='Close', axis=1, level='Stock Info').iplot()
# Out:
# <div>                            <div id="4fa0ccda-a832-4221-ab28-db05af238c7e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Averages

# %% [markdown]
# Plot the rolling 30 day average against the close price for Bank of Americas stock for the year 2008

# %%
BAC.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  33.942665
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  33.582176
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  33.625446
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  33.574966
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  33.596596

# %%
plt.figure(figsize=(20,10))
BAC['Close'].loc['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 day moving avg')
BAC['Close'].loc['2008-01-01':'2009-01-01'].plot(label='BAC Close')
plt.legend()

# %% [markdown]
# Create a heatmap of the correlation between the stocks Close Price

# %%
bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr()
# Out:
# Bank Ticker       BAC         C        GS       JPM        MS       WFC
# Bank Ticker
# BAC          1.000000  0.971516  0.550898  0.103874  0.944218  0.008542
# C            0.971516  1.000000  0.434123  0.003515  0.933609 -0.068536
# GS           0.550898  0.434123  1.000000  0.685286  0.683792  0.499897
# JPM          0.103874  0.003515  0.685286  1.000000  0.250427  0.940269
# MS           0.944218  0.933609  0.683792  0.250427  1.000000  0.131835
# WFC          0.008542 -0.068536  0.499897  0.940269  0.131835  1.000000

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data=bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(), annot=True)
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %%
plt.figure(figsize=(20,10))
sns.clustermap(data=bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(), annot=True)

# %% [markdown]
# Candle stick plot

# %%
bac15 = BAC[['Open', 'High', 'Low', 'Close']].loc['2015-01-01':'2016-01-01']
bac15.iplot(kind='candle')
# Out:
# <div>                            <div id="67f1ce09-48f1-402f-92f0-8aa59fda6aaf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# Moving average plot

# %%
MS['Close'].loc['2015-01-01':'2016-01-01'].ta_plot(study='sma', periods=[13,21,55])
# Out:
# <div>                            <div id="bc702bda-3246-425e-a509-8e3967537ecc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
