# %% [markdown]
# To solve binary classification problems
# - Spam: Yes/No
# - Diagnoses: Cancer Yes/No
#
# vs. linear regression:
# - Linear: Regression problems with continous values
# - Logistic: Regression for classification
#
# Logistic curve can only go between 0,1 (its output) -> Sigmoid Function
#
# ![](logistic.jpg)
#
# Anything below 0.5 will go to class 0, above to class 1. So based of the probability output we assign a class

# %% [markdown]
# # Evaluation
# - Using confusion matrix to evaluate classification models
# - in this example, 165 patients were tested
#
# ![](confusion2.jpg)
#
# Now calculate accuracy:
# - (TP + TN) / total = 0.91
#
# And missclassification rate:
# - (FP + FN) / total = 0.09
