# %% [markdown]
# Supervised learning models
# - classification
# - regression

# %% [markdown]
# How it works:
# - SVM represents the samples as points in space.
# - These points are mapped so that the samples of each category are divided by a clear gap
# - New samples are then mapped into that same space and predicted to belong to a category

# %% [markdown]
# Intuition:
#
# ![](svm_1.jpg)

# %% [markdown]
# However, we have multiple seperate lines (hyperplane)
#
# ![](svm_2.jpg)

# %% [markdown]
# - We would like to choose the hyperplane that maximizes the margin between the classes
# - This is the dotted hyperplane and the margin is the solid line
# - The vector points that touches the margin line are the "Support Vectors"
#
# ![](svm_3.jpg)

# %% [markdown]
# - We can expand this idea to non-linear seperable data using the "Kernel Trick"
# - We expand the dimensions
#
# ![](svm_4.jpg)
